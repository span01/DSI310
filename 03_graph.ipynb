# %% [markdown]
# # 03_graph
# - process news SPO analytics via graph algorithm

# %% [markdown]
# ### install extra library

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (2.8.5)

# %% [markdown]
# ### read Web Scraping BBC from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
from tqdm.auto import tqdm

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY2ODkwNDQ3LCJpYXQiOjE2NjY2Nzk3NTEsImp0aSI6IjAwZGJiNzcyZTU5MTRlNzRiYWZjZjZmZTE4ZDBkMzRhIiwidXNlcl9pZCI6MTd9.mI9CovoPLk2hJ3vWpiVQiHhdBUOLK5GoUw_6fhUvY-M"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
dir_process_id = 122

# %%
df = datanode.read_df(datanode.get_file_id(directory_id=dir_process_id, name="BBC News : Coffee news Scraping.parquet"))
df
# Out:
#                                                  Title  \
# 0    The Muhammadan Bean: The Secret History of Isl...
# 1                              Coffee - a Hellish Brew
# 2                           David White's Coffee Break
# 3                           Jill Scottâs Coffee Club
# 4                                   Cuppy's Coffee Mix
# ..                                                 ...
# 285                         Spice Taxi: Eritrea Coffee
# 286  Fancy a cuppa coffee? Lisburn company plans to...
# 287  Llandudno woman was crushed by mobile coffee s...
# 288  Coffee - a Hellish Brew: Coffee Growing and Pr...
# 289  The Farming World: How can Coffee Growers make...
#
#                                                Details
# 0    Abdul-Rehman Malik explores the longstanding r...
# 1    Series tracing the history and impact of coffe...
# 2    Join David for some fun and games as you take ...
# 3    Jill Scottâs Coffee Club brings you an intim...
# 4                                   Cuppy's Coffee Mix
# ..                                                 ...
# 285  The significance of making coffee in Eritrea -...
# 286  Take a coffee plant and some volcanic soil, ke...
# 287  The exact circumstances leading to Tracy Evans...
# 288  The social and economic importance of coffee p...
# 289  It's hard to make a profit when coffee changes...
#
# [290 rows x 2 columns]

# %% [markdown]
# ### prepair graph data

# %%
graph_data = [(elm.get('Title'), elm.get('Datails')) for elm in df.to_dict('records')]
graph_data
# Out:
# [('The Muhammadan Bean: The Secret History of Islam and Coffee', None),
#  ('Coffee - a Hellish Brew', None),
#  ("David White's Coffee Break", None),
#  ('Jill Scottâ\x80\x99s Coffee Club', None),
#  ("Cuppy's Coffee Mix", None),
#  ('How to Make the Perfect Coffee', None),
#  ("International Women's Day Coffee Concert", None),
#  ('The Partisan Coffee House', None),
#  ('Man arrested after woman stabbed in Edgware Road coffee shop', None),
#  ("Calf's Head and Coffee: The Golden Age of English Food", None),
#  ("David White's Coffee Break: James Dundon sits in (18/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (17/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (16/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (15/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (14/11/2022)", None),
#  ('The Late Show with Eve Blair: Fall Coffee Collective, Laura Zocca, Rita Wilson',
#   None),
#  ('Karnataka: Female Dalit coffee workers accuse boss of locking them up',
#   None),
#  ('Jon Wright: A fresh start... and coffee', None),
#  ('Bristol coffee shop saved from closure by crowdfunder', None),
#  ('Caffeine hit: Battle of the baristas for coffee lovers', None),
#  ("David White's Coffee Break: James Dundon sits in (11/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (10/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (09/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (08/11/2022)", None),
#  ("David White's Coffee Break: James Dundon sits in (07/11/2022)", None),
#  ("David White's Coffee Break: 26/10/2022", None),
#  ("David White's Coffee Break: 25/10/2022", None),
#  ("David White's Coffee Break: 24/10/2022", None),
#  ('Annabel Amos: Dogs, U-turns and coffee', None),
#  ("David White's Coffee Break: 21/10/2022", None),
#  ("David White's Coffee Break: 20/10/2022", None),
#  ("David White's Coffee Break: 19/10/2022", None),
#  ("David White's Coffee Break: 18/10/2022", None),
#  ("David White's Coffee Break: 17/10/2022", None),
#  ("David White's Coffee Break: 14/10/2022", None),
#  ("David White's Coffee Break: 06/10/2022", None),
#  ("David White's Coffee Break: 13/10/2022", None),
#  ("David White's Coffee Break: 12/10/2022", None),
#  ("David White's Coffee Break: 11/10/2022", None),
#  ("David White's Coffee Break: 10/10/2022", None),
#  ("David White's Coffee Break: 07/10/2022", None),
#  ("David White's Coffee Break: 05/10/2022", None),
#  ("David White's Coffee Break: 04/10/2022", None),
#  ("David White's Coffee Break: 03/10/2022", None),
#  ("David White's Coffee Break: 04/11/2022", None),
#  ("David White's Coffee Break: 03/11/2022", None),
#  ("David White's Coffee Break: 02/11/2022", None),
#  ("David White's Coffee Break: 01/11/2022", None),
#  ("David White's Coffee Break: 31/10/2022", None),
#  ("David White's Coffee Break: 28/10/2022", None),
#  ("David White's Coffee Break: 27/10/2022", None),
#  ("'Coffee and sausage rolls kept Queen queue going'", None),
#  ('5 Live Science Podcast: Moderna vs Pfizer, Marijuana, Coffee and Cancer, and water water not everywh',
#   None),
#  ('Russia Starbucks: Home-grown chain Stars replaces coffee giant', None),
#  ('Coffee machines worth Â£300k stolen from Birmingham warehouse', None),
#  ('Coffee machines worth Â£300,000 stolen from Birmingham warehouse', None),
#  ('Jeremiah Asiamah: Get Lit Mix: Best of Black Coffee!', None),
#  ('The tech helping to bring you your morning coffee', None),
#  ('You and Yours: Coffee, New Cars and Passport Couriers', None),
#  ('5 Live Science Podcast: Moderna sue Pfizer, are cannabis users more laid back, does coffee cause can',
#   None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Best Bits: Leah Williamson, Ellen White, Mary Earps & Ella Toone',
#   None),
#  ('You and Yours: Holiday Home Spoofing,  Consumer Panel and Indy Coffee Shops',
#   None),
#  ("Bristol Somali women's coffee-mornings at risk", None),
#  ('5 Live Science: Moderna vs Pfizer, Marijuana, Coffee and Cancer, and water water not everywhere...',
#   None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Series finale: Lucy Staniforth, Thierry Henry & proposals',
#   None),
#  ('Cocaine found in coffee sent to Nespresso plant', None),
#  ('Just One Thing - with Michael Mosley: Drink Coffee', None),
#  ("DR Congo: 'My life has changed thanks to coffee'", None),
#  ("5 Live Sport: Jill Scott's Coffee Club", None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Steph Houghton, scooters & a horse',
#   None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Rachel Yankey, worldies & fig rolls',
#   None),
#  ('Ukraine: The bride who fled to India from Kyiv with a coffee machine',
#   None),
#  ("6 Minute English: Britain's love affair with coffee", None),
#  ("Cuppy's Coffee Mix: National Parents' Day Mix", None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Jen Beattie, Erin Cuthbert & Primrose Hill',
#   None),
#  ("Cuppy's Coffee Mix: 14/08/2022", None),
#  ('A specialty coffee wave is brewing in India', None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Leah Williamson, pool disasters & plane dramas',
#   None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Demi Stokes, motherhood & Christmas shopping',
#   None),
#  ("Cuppy's Coffee Mix: 07/08/2022", None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Rachel Furness, Simone Magill & snoring',
#   None),
#  ('5 Live Science Podcast: Wake up and smell the coffeeâ\x80¦', None),
#  ("5 Live Sport: Jill Scott's Coffee Club: 01/08/2022", None),
#  ("5 Live Sport: Jill Scott's Coffee Club: Jill Scott's Coffee Club Lioness Special",
#   None),
#  ("The Food Programme: Fresh Grounds: The Search for the World's Rarest Coffee",
#   None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Mary Earps, rollerblading & scrambled eggs',
#   None),
#  ("Cuppy's Coffee Mix: 31/07/2022", None),
#  ('Simon Evans Goes to Market: Series 2: Coffee', None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Ella Toone, Ibiza & Norman the dog',
#   None),
#  ("5 Live Sport: Jill Scott's Coffee Club: 29/07/2022", None),
#  ('Black Coffee - the South African DJ who made history at the Grammys', None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Coffee, freebies & bar-hopping in Nashville',
#   None),
#  ('Jill Scottâ\x80\x99s Coffee Club: Ellen White, Prince William & a broken nose',
#   None),
#  ('Coffee cup charge plans set to be re-introduced', None),
#  ("Cuppy's Coffee Mix: Glastonbury Festival Mix", None),
#  ('Witness History: The Trojan Room Coffee Pot', None),
#  ('Witness History: The Trojan Room Coffee Pot', None),
#  ('Fortunately... with Fi and Jane: 227. Drinking coffee in unison with Tim Lovejoy and Simon Rimmer',
#   None),
#  ('Finla Coffee: Shop loses Covid-19 breach appeal but fine is halved', None),
#  ('Waitrose free coffee will have a trial return in some stores', None),
#  ("Cuppy's Coffee Mix: 17/07/2022", None),
#  ('Colwyn Bay man died after 200-coffee caffeine overdose', None),
#  ("Cuppy's Coffee Mix: Cuppy's Father's Day Hip Hop Mix (Presented by Fee Mak)",
#   None),
#  ('This World: The Coffee Trail with Simon Reeve', None),
#  ('Africa Daily: Why are Ugandaâ\x80\x99s coffee exports booming?', None),
#  ("The World at One Highlights: Coffee & refuge in Kyiv's Buena Vista Social Bar",
#   None),
#  ("Cuppy's Coffee Mix: 10/07/2022", None),
#  ("5 Live Sport: Jill Scott's Coffee Club: 27/06/2022", None),
#  ("5 Live Sport: Jill Scott's Coffee Club: 30/06/2022", None),
#  ('Pret raises the price of its coffee subscription by 25%', None),
#  ("Cuppy's Coffee Mix: Cuppy's Best Friend Mix", None),
#  ("Record Review Podcast: Bach's Coffee Cantata", None),
#  ('Fortunately... with Fi and Jane: 222. Coffee, Soap and Timekeeping with Jess Salomon and Eman El-Hus',
#   None),
#  ("Cuppy's Coffee Mix: 03/07/2022", None),
#  ('Vietnam lockdown adds to global coffee supply concerns', None),
#  ("Cuppy's Coffee Mix: Jubilee Special: Queens of Music", None),
#  ('Tokyo Olympics: Armand Duplantis glad to have avoided coffee with Sam Kendricks',
#   None),
#  ('Plymouth coffee shop fined Â£42K for Covid breach', None),
#  ("5 Live Sport: Jill Scott's Coffee Club: Rachel Furness, Simone Magill & snoring",
#   None),
#  ('GPs prescribe coffee at Hartlepool cafe to combat loneliness', None),
#  ('The Train at Platform 4: Coffee', None),
#  ('Councils start collecting coffee pods with recycling', None),
#  ('Cooking with Paula McIntyre: Chocolate Coffee Fudge Cakes', None),
#  ('Climate change: Future-proofing coffee in a warming world', None),
#  ('Coffee waste: Companies offer up new solutions', None),
#  ('BBC Inside Science: Coronavirus variants and vaccines, climate change resistant coffee, dare to repa',
#   None),
#  ('Geraint Thomas reunited with bike stolen during coffee stop', None),
#  ('David White: Sharon Corr, Silly Survey, Coffee Break Question (18/05/2022)',
#   None),
#  ('Science In Action: Melting glaciers, warming coffee and a Dragonfly on Titan',
#   None),
#  ('The coffee start-ups brewing up a storm in lockdown', None),
#  ("CEO Secrets: The woman brewing up 'bromances' over coffee", None),
#  ('Forest Green Rovers to wear shirts made of coffee waste', None),
#  ('Africa Daily: Is coffee the future for South Sudan?', None),
#  ('Will coffee drinkers plump for potato milk?', None),
#  ("No pickers, no coffee: How Covid threatens Colombia's harvest", None),
#  ('Devon food bank sees 26-year-old coffee packet handed in', None),
#  ('From Our Own Correspondent: Columbian Coffee Growers Face Stark Choice',
#   None),
#  ("'I've raised Â£100,000 after 24 years of coffee mornings'", None),
#  ('Brexit: Coffee cup confusion - the Internal Market Bill explained', None),
#  ('Plympton coffee shop ordered to stop flouting lockdown rules', None),
#  ("Cleaner Aurora Iacomi jailed for spiking boss's coffee with detergent",
#   None),
#  ('Jim Hawkins: Tom Matthews from the Nerdy Coffee Co. in Shrewsbury is in The Cool Seat today (09/06/2',
#   None),
#  ('Costa Coffee warns up to 1,650 jobs are at risk', None),
#  ("Pat Cummins column: Australia's coffee lovers, golf bandit and WhatsApp jokes",
#   None),
#  ('World Snooker Championship: Neil Robertson spills coffee', None),
#  ('World Business Report: Egypt: Coronavirus and coffee', None),
#  ("Coronavirus coffee farmer: 'We're definitely scared'", None),
#  ('Witness History: The Trojan Room coffee pot', None),
#  ('Bristol coffee cup recycling scheme set to be expanded', None),
#  ('Cooking in a Bedsitter: Series 1: Coffee Chiffon', None),
#  ('Coronavirus: Owner closes coffee shop chain during outbreak', None),
#  ('Coffee, from Italy to Wales: the story of Italian cafes', None),
#  ('Oldham paedophile set up coffee shop to lure teenage boys', None),
#  ('In Our Time: Coffee', None),
#  ('Latte artist dreams of world coffee success', None),
#  ('Andrew Salter column: T20 Blast, Marnus, bikes and coffee', None),
#  ('New life brewed for 100-year-old East End coffee stall', None),
#  ("Britain's love affair with coffee", None),
#  ("Switzerland's plan to stop stockpiling coffee proves hard to swallow",
#   None),
#  ('Entrepreneurs: From coal to coffee in ex-mining town', None),
#  ("220407 - 6 Minute English - Britain's love affair with coffee MAP", None),
#  ('VG Siddhartha: The coffee king of India', None),
#  ("Game of Thrones' coffee cup and 6 other TV and film bloopers", None),
#  ('The Kitchen CafÃ©: Street Food, Horsebox Trailer Coffee & Pairing Whisky And Food',
#   None),
#  ("VG Siddhartha: Cafe Coffee Day tycoon's body found", None),
#  ('How the 2019 coffee crisis might affect you', None),
#  ('VG Siddhartha: Cafe Coffee Day owner goes missing near river', None),
#  ('Jeremiah Asiamah: Get Lit Mix: Best of Black Coffee!', None),
#  ("Costa Coffee: Employees call Â£200 deductions for training 'unfair'", None),
#  ('Jerry Seinfeld wins copyright lawsuit over Comedians in Cars Getting Coffee',
#   None),
#  ('Reading coffee shop helping women rebuild their lives', None),
#  ('Vegan chicken fillet roll copycat row bites Insomnia Coffee', None),
#  ('A coffee shop in San Francisco offers a $75 cup of coffee', None),
#  ('Bulletproof coffee: Would you add butter to your brew?', None),
#  ('San Francisco is serving up a $75 cup of coffee', None),
#  ("Faf de Klerk: Pants, coffee and Shrek: Q&A with South Africa's World Cup winner",
#   None),
#  ('Coffee art: Why Ennock Mlangeni swapped paint for the bean', None),
#  ('Purr-fect place for a coffee', None),
#  ('Coffee not essential for life, Swiss government says', None),
#  ("Coffee waste 'could replace palm oil'", None),
#  ("Coffee cup ban: Boston Tea Party's sales fall by Â£250k", None),
#  ('Coffee species face extinction, report says', None),
#  ("Cuppy: Cuppy & Eddie Kadi get heated over pancakes Plus special Cuppy's Coffee Mix",
#   None),
#  ('Cannabis with your coffee?', None),
#  ('Wormwood Scrubs inmates train to become coffee baristas', None),
#  ('Taking the coffee bean to the barista', None),
#  ("In Business: Colombia's Coffee Revolutions", None),
#  ('The Florida coffee shop where Trump is king', None),
#  ('Boston Tea Party coffee chain boss on Â£250k loss', None),
#  ("Single-use coffee cups: Wales urged to bring in 'latte levy'", None),
#  ("'Keep Frank's Bethnal Green coffee stand open'", None),
#  ('Christchurch council refuses permission for new coffee shop', None),
#  ("Cannabis in coffee: 'Just like having a shot of syrup'", None),
#  ('The Why Factor: Coffee', None),
#  ('The Food Chain: Coffee: Globalisationâ\x80\x99s Drink of Choice', None),
#  ('Global Business: Colombiaâ\x80\x99s Coffee Revolutions', None),
#  ('The World of Business: Colombiaâ\x80\x99s Coffee Revolutions', None),
#  ('Your pictures: Coffee time', None),
#  ('Talks between Douwe Egberts and coffee workers break down', None),
#  ('Coffee delivery drone patented by IBM', None),
#  ('Why Bosnian coffee is served with sherbet', None),
#  ('Coca-Cola to buy Costa coffee for Â£3.9bn', None),
#  ('Welsh roastery Coaltown Coffee named in Lonely Planet list', None),
#  ('Coffee: Who grows, drinks and pays the most?', None),
#  ('The coffee cup which can be recycled in existing systems', None),
#  ('Best of Friends: Fancy grabbing a coffee at Central Perk?', None),
#  ("Back to school: 'I'm ready for a coffee in peace'", None),
#  ('Disposable coffee cup bans unnecessary, says manufacturer', None),
#  ('Coffee sold in California must carry cancer warning, judge rules', None),
#  ('Coffee war brews in the land of tea', None),
#  ('Plastic recycling: Why are 99.75% of coffee cups not recycled?', None),
#  ("Coffee chain Boston Tea Party 'first' to ban disposable cups", None),
#  ("Costa Coffee vows 'cup recycling revolution'", None),
#  ("Liam Williams column: Old friends, no fans and George North's coffee skills",
#   None),
#  ("Gardeners' Corner: Coffee grounds, sweet pea and Matthew Wilson", None),
#  ('The Documentary: Your Life in a Cup of Coffee', None),
#  ('The Documentary Podcast: Your Life in a Cup of Coffee', None),
#  ("Three cups of coffee a day 'may have health benefits'", None),
#  ('How changing coffee tastes are helping farmers', None),
#  ('Costa Coffee advert banned for criticising avocado breakfasts', None),
#  ('London buses to be powered by coffee', None),
#  ("'Want a cup of coffee? That'll be $60'", None),
#  ("Why Italians are saying 'no' to takeaway coffee", None),
#  ('Smart Consumer: The You and Yours Coffee Break. What are you eating and who are going to you watch?',
#   None),
#  ('The Italians who prefer to drink American coffee', None),
#  ('The coffee cups that get you to talk', None),
#  ('Is the UK reaching coffee shop saturation point?', None),
#  ('Nestle swallows Blue Bottle Coffee', None),
#  ("How 'posh coffee' is helping farmers", None),
#  ('Reading coffee shops offer discount on reusable cups', None),
#  ('Faecal bacteria found in coffee shop ice after random checks', None),
#  ("Costa coffee chain's profits go cold", None),
#  ('CCTV of masked men beating coffee shop staff with bats', None),
#  ('Four solutions to the disposable coffee cup problem', None),
#  ('Ellia Smeding & Cornelius Kersten: Speed skating couple using coffee to fund Olympic dream',
#   None),
#  ('Covid: Portsdown Hill coffee drinker fined for refusing to leave', None),
#  ("Why Italians are saying 'No' to takeaway coffee", None),
#  ("'Latte levy': Would you pay 25p for your coffee cup?", None),
#  ("Ireland considers 'coffee tax' to cut back on disposable cups", None),
#  ('Will coffee taste worse as the planet warms?', None),
#  ('Checks on Welsh coffee shops for faecal bacteria in ice', None),
#  ("'Suspended coffee' initiative taking off in Bristol", None),
#  ('Orkney gets first coffee roastery', None),
#  ('Suffolk Rural Coffee Caravan wants to replace stolen vehicle', None),
#  ('Coffee cup fee could cut use by 300 million, study suggests', None),
#  ('Coffee cup recycling scheme launched in City of London', None),
#  ("Costa Coffee's High Street sales fall", None),
#  ('You and Yours: Christmas Shopping; Coffee Shop decline; Relaxed Tailoring',
#   None),
#  ('Maths zeroes in on perfect cup of coffee', None),
#  ('CEO Secrets: Think outside the bubble, says coffee chief', None),
#  ('What makes your perfect cup of coffee?', None),
#  ('Manchester launches paper coffee cup recycling campaign', None),
#  ("Cambridge police cell detainee donates scratchcard win for 'better coffee' in cells",
#   None),
#  ('Waitrose coffee change gives grounds for complaint', None),
#  ('Costa coffee owner Whitbread wary over prospects', None),
#  ("Study finds gene 'that could curb coffee consumption'", None),
#  ('How do you turn used coffee grounds into clothes?', None),
#  ('Four Thought: Coffee with an Imam', None),
#  ('Natalie Bennett angry as GWR refuse coffee in reusable cup', None),
#  ('Man admits Westerham Costa coffee death crash', None),
#  ('Glasgow coffee supplier Matthew Algie sold to Tchibo', None),
#  ("'Hipster coffee' gets Australia hot and frothing", None),
#  ('Viewpoint: The waste mountain of coffee cups', None),
#  ('Coffee shops on the march as pubs decline, town centre data shows', None),
#  ('Why your coffee could cost more', None),
#  ('Why your coffee could cost more', None),
#  ("Indonesia 'coffee killer' trial: Jessica Wongso found guilty of murder",
#   None),
#  ("'Russiano' coffee joke sparks online humour", None),
#  ('Cancer risk from coffee downgraded', None),
#  ('Is there a serious problem with coffee capsules?', None),
#  ('Queen portrait created out of 1,600 used coffee pods', None),
#  ('Costa Coffee helps boost Whitbread profits', None),
#  ('MSPs call for better quality coffee at Holyrood committee meetings', None),
#  ('Your pictures: Coffee break', None),
#  ('Coffee - a Hellish Brew: Slurping Coffee for a Living', None),
#  ("MSP Mary Scanlon makes plea for 'decent coffee' at Holyrood", None),
#  ('Westerham Costa Coffee death crash: Man, 86, to face charges', None),
#  ('Westerham Costa coffee death crash: David Lord charged', None),
#  ('Discovery: The coffee trade', None),
#  ('Green entrepreneurs: Coffee for your face, bees for your booze', None),
#  ('The Farming World: Coffee Fungus Spreads into Uguanda', None),
#  ('Entrepreneur milks new coffee trend in Ivory Coast', None),
#  ('Coffee maker Keurig sells to Douwe Egberts owner for $13.9bn', None),
#  ("Who'd have Thought It?: Coffee", None),
#  ('Man denies Westerham Costa coffee death crash', None),
#  ('Spice Taxi: Eritrea Coffee', None),
#  ('Fancy a cuppa coffee? Lisburn company plans to brew success', None),
#  ('Llandudno woman was crushed by mobile coffee shop van', None),
#  ('Coffee - a Hellish Brew: Coffee Growing and Production', None),
#  ('The Farming World: How can Coffee Growers make a Profit?', None)]

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

from bokeh.io import output_notebook, show, save
from bokeh.models import Range1d, Circle, ColumnDataSource, MultiLine
from bokeh.plotting import figure
from bokeh.plotting import from_networkx

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
'''
use for clear bokeh plot
'''
# from bokeh.io import curdoc
# curdoc().clear()
# Out:
# '\nuse for clear bokeh plot\n'

# %%
news_titles = {elm:'name' for elm in list(df['Title'].unique())}
news_titles
# Out:
# {'The Muhammadan Bean: The Secret History of Islam and Coffee': 'name',
#  'Coffee - a Hellish Brew': 'name',
#  "David White's Coffee Break": 'name',
#  'Jill Scottâ\x80\x99s Coffee Club': 'name',
#  "Cuppy's Coffee Mix": 'name',
#  'How to Make the Perfect Coffee': 'name',
#  "International Women's Day Coffee Concert": 'name',
#  'The Partisan Coffee House': 'name',
#  'Man arrested after woman stabbed in Edgware Road coffee shop': 'name',
#  "Calf's Head and Coffee: The Golden Age of English Food": 'name',
#  "David White's Coffee Break: James Dundon sits in (18/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (17/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (16/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (15/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (14/11/2022)": 'name',
#  'The Late Show with Eve Blair: Fall Coffee Collective, Laura Zocca, Rita Wilson': 'name',
#  'Karnataka: Female Dalit coffee workers accuse boss of locking them up': 'name',
#  'Jon Wright: A fresh start... and coffee': 'name',
#  'Bristol coffee shop saved from closure by crowdfunder': 'name',
#  'Caffeine hit: Battle of the baristas for coffee lovers': 'name',
#  "David White's Coffee Break: James Dundon sits in (11/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (10/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (09/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (08/11/2022)": 'name',
#  "David White's Coffee Break: James Dundon sits in (07/11/2022)": 'name',
#  "David White's Coffee Break: 26/10/2022": 'name',
#  "David White's Coffee Break: 25/10/2022": 'name',
#  "David White's Coffee Break: 24/10/2022": 'name',
#  'Annabel Amos: Dogs, U-turns and coffee': 'name',
#  "David White's Coffee Break: 21/10/2022": 'name',
#  "David White's Coffee Break: 20/10/2022": 'name',
#  "David White's Coffee Break: 19/10/2022": 'name',
#  "David White's Coffee Break: 18/10/2022": 'name',
#  "David White's Coffee Break: 17/10/2022": 'name',
#  "David White's Coffee Break: 14/10/2022": 'name',
#  "David White's Coffee Break: 06/10/2022": 'name',
#  "David White's Coffee Break: 13/10/2022": 'name',
#  "David White's Coffee Break: 12/10/2022": 'name',
#  "David White's Coffee Break: 11/10/2022": 'name',
#  "David White's Coffee Break: 10/10/2022": 'name',
#  "David White's Coffee Break: 07/10/2022": 'name',
#  "David White's Coffee Break: 05/10/2022": 'name',
#  "David White's Coffee Break: 04/10/2022": 'name',
#  "David White's Coffee Break: 03/10/2022": 'name',
#  "David White's Coffee Break: 04/11/2022": 'name',
#  "David White's Coffee Break: 03/11/2022": 'name',
#  "David White's Coffee Break: 02/11/2022": 'name',
#  "David White's Coffee Break: 01/11/2022": 'name',
#  "David White's Coffee Break: 31/10/2022": 'name',
#  "David White's Coffee Break: 28/10/2022": 'name',
#  "David White's Coffee Break: 27/10/2022": 'name',
#  "'Coffee and sausage rolls kept Queen queue going'": 'name',
#  '5 Live Science Podcast: Moderna vs Pfizer, Marijuana, Coffee and Cancer, and water water not everywh': 'name',
#  'Russia Starbucks: Home-grown chain Stars replaces coffee giant': 'name',
#  'Coffee machines worth Â£300k stolen from Birmingham warehouse': 'name',
#  'Coffee machines worth Â£300,000 stolen from Birmingham warehouse': 'name',
#  'Jeremiah Asiamah: Get Lit Mix: Best of Black Coffee!': 'name',
#  'The tech helping to bring you your morning coffee': 'name',
#  'You and Yours: Coffee, New Cars and Passport Couriers': 'name',
#  '5 Live Science Podcast: Moderna sue Pfizer, are cannabis users more laid back, does coffee cause can': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Best Bits: Leah Williamson, Ellen White, Mary Earps & Ella Toone': 'name',
#  'You and Yours: Holiday Home Spoofing,  Consumer Panel and Indy Coffee Shops': 'name',
#  "Bristol Somali women's coffee-mornings at risk": 'name',
#  '5 Live Science: Moderna vs Pfizer, Marijuana, Coffee and Cancer, and water water not everywhere...': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Series finale: Lucy Staniforth, Thierry Henry & proposals': 'name',
#  'Cocaine found in coffee sent to Nespresso plant': 'name',
#  'Just One Thing - with Michael Mosley: Drink Coffee': 'name',
#  "DR Congo: 'My life has changed thanks to coffee'": 'name',
#  "5 Live Sport: Jill Scott's Coffee Club": 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Steph Houghton, scooters & a horse': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Rachel Yankey, worldies & fig rolls': 'name',
#  'Ukraine: The bride who fled to India from Kyiv with a coffee machine': 'name',
#  "6 Minute English: Britain's love affair with coffee": 'name',
#  "Cuppy's Coffee Mix: National Parents' Day Mix": 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Jen Beattie, Erin Cuthbert & Primrose Hill': 'name',
#  "Cuppy's Coffee Mix: 14/08/2022": 'name',
#  'A specialty coffee wave is brewing in India': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Leah Williamson, pool disasters & plane dramas': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Demi Stokes, motherhood & Christmas shopping': 'name',
#  "Cuppy's Coffee Mix: 07/08/2022": 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Rachel Furness, Simone Magill & snoring': 'name',
#  '5 Live Science Podcast: Wake up and smell the coffeeâ\x80¦': 'name',
#  "5 Live Sport: Jill Scott's Coffee Club: 01/08/2022": 'name',
#  "5 Live Sport: Jill Scott's Coffee Club: Jill Scott's Coffee Club Lioness Special": 'name',
#  "The Food Programme: Fresh Grounds: The Search for the World's Rarest Coffee": 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Mary Earps, rollerblading & scrambled eggs': 'name',
#  "Cuppy's Coffee Mix: 31/07/2022": 'name',
#  'Simon Evans Goes to Market: Series 2: Coffee': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Ella Toone, Ibiza & Norman the dog': 'name',
#  "5 Live Sport: Jill Scott's Coffee Club: 29/07/2022": 'name',
#  'Black Coffee - the South African DJ who made history at the Grammys': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Coffee, freebies & bar-hopping in Nashville': 'name',
#  'Jill Scottâ\x80\x99s Coffee Club: Ellen White, Prince William & a broken nose': 'name',
#  'Coffee cup charge plans set to be re-introduced': 'name',
#  "Cuppy's Coffee Mix: Glastonbury Festival Mix": 'name',
#  'Witness History: The Trojan Room Coffee Pot': 'name',
#  'Fortunately... with Fi and Jane: 227. Drinking coffee in unison with Tim Lovejoy and Simon Rimmer': 'name',
#  'Finla Coffee: Shop loses Covid-19 breach appeal but fine is halved': 'name',
#  'Waitrose free coffee will have a trial return in some stores': 'name',
#  "Cuppy's Coffee Mix: 17/07/2022": 'name',
#  'Colwyn Bay man died after 200-coffee caffeine overdose': 'name',
#  "Cuppy's Coffee Mix: Cuppy's Father's Day Hip Hop Mix (Presented by Fee Mak)": 'name',
#  'This World: The Coffee Trail with Simon Reeve': 'name',
#  'Africa Daily: Why are Ugandaâ\x80\x99s coffee exports booming?': 'name',
#  "The World at One Highlights: Coffee & refuge in Kyiv's Buena Vista Social Bar": 'name',
#  "Cuppy's Coffee Mix: 10/07/2022": 'name',
#  "5 Live Sport: Jill Scott's Coffee Club: 27/06/2022": 'name',
#  "5 Live Sport: Jill Scott's Coffee Club: 30/06/2022": 'name',
#  'Pret raises the price of its coffee subscription by 25%': 'name',
#  "Cuppy's Coffee Mix: Cuppy's Best Friend Mix": 'name',
#  "Record Review Podcast: Bach's Coffee Cantata": 'name',
#  'Fortunately... with Fi and Jane: 222. Coffee, Soap and Timekeeping with Jess Salomon and Eman El-Hus': 'name',
#  "Cuppy's Coffee Mix: 03/07/2022": 'name',
#  'Vietnam lockdown adds to global coffee supply concerns': 'name',
#  "Cuppy's Coffee Mix: Jubilee Special: Queens of Music": 'name',
#  'Tokyo Olympics: Armand Duplantis glad to have avoided coffee with Sam Kendricks': 'name',
#  'Plymouth coffee shop fined Â£42K for Covid breach': 'name',
#  "5 Live Sport: Jill Scott's Coffee Club: Rachel Furness, Simone Magill & snoring": 'name',
#  'GPs prescribe coffee at Hartlepool cafe to combat loneliness': 'name',
#  'The Train at Platform 4: Coffee': 'name',
#  'Councils start collecting coffee pods with recycling': 'name',
#  'Cooking with Paula McIntyre: Chocolate Coffee Fudge Cakes': 'name',
#  'Climate change: Future-proofing coffee in a warming world': 'name',
#  'Coffee waste: Companies offer up new solutions': 'name',
#  'BBC Inside Science: Coronavirus variants and vaccines, climate change resistant coffee, dare to repa': 'name',
#  'Geraint Thomas reunited with bike stolen during coffee stop': 'name',
#  'David White: Sharon Corr, Silly Survey, Coffee Break Question (18/05/2022)': 'name',
#  'Science In Action: Melting glaciers, warming coffee and a Dragonfly on Titan': 'name',
#  'The coffee start-ups brewing up a storm in lockdown': 'name',
#  "CEO Secrets: The woman brewing up 'bromances' over coffee": 'name',
#  'Forest Green Rovers to wear shirts made of coffee waste': 'name',
#  'Africa Daily: Is coffee the future for South Sudan?': 'name',
#  'Will coffee drinkers plump for potato milk?': 'name',
#  "No pickers, no coffee: How Covid threatens Colombia's harvest": 'name',
#  'Devon food bank sees 26-year-old coffee packet handed in': 'name',
#  'From Our Own Correspondent: Columbian Coffee Growers Face Stark Choice': 'name',
#  "'I've raised Â£100,000 after 24 years of coffee mornings'": 'name',
#  'Brexit: Coffee cup confusion - the Internal Market Bill explained': 'name',
#  'Plympton coffee shop ordered to stop flouting lockdown rules': 'name',
#  "Cleaner Aurora Iacomi jailed for spiking boss's coffee with detergent": 'name',
#  'Jim Hawkins: Tom Matthews from the Nerdy Coffee Co. in Shrewsbury is in The Cool Seat today (09/06/2': 'name',
#  'Costa Coffee warns up to 1,650 jobs are at risk': 'name',
#  "Pat Cummins column: Australia's coffee lovers, golf bandit and WhatsApp jokes": 'name',
#  'World Snooker Championship: Neil Robertson spills coffee': 'name',
#  'World Business Report: Egypt: Coronavirus and coffee': 'name',
#  "Coronavirus coffee farmer: 'We're definitely scared'": 'name',
#  'Witness History: The Trojan Room coffee pot': 'name',
#  'Bristol coffee cup recycling scheme set to be expanded': 'name',
#  'Cooking in a Bedsitter: Series 1: Coffee Chiffon': 'name',
#  'Coronavirus: Owner closes coffee shop chain during outbreak': 'name',
#  'Coffee, from Italy to Wales: the story of Italian cafes': 'name',
#  'Oldham paedophile set up coffee shop to lure teenage boys': 'name',
#  'In Our Time: Coffee': 'name',
#  'Latte artist dreams of world coffee success': 'name',
#  'Andrew Salter column: T20 Blast, Marnus, bikes and coffee': 'name',
#  'New life brewed for 100-year-old East End coffee stall': 'name',
#  "Britain's love affair with coffee": 'name',
#  "Switzerland's plan to stop stockpiling coffee proves hard to swallow": 'name',
#  'Entrepreneurs: From coal to coffee in ex-mining town': 'name',
#  "220407 - 6 Minute English - Britain's love affair with coffee MAP": 'name',
#  'VG Siddhartha: The coffee king of India': 'name',
#  "Game of Thrones' coffee cup and 6 other TV and film bloopers": 'name',
#  'The Kitchen CafÃ©: Street Food, Horsebox Trailer Coffee & Pairing Whisky And Food': 'name',
#  "VG Siddhartha: Cafe Coffee Day tycoon's body found": 'name',
#  'How the 2019 coffee crisis might affect you': 'name',
#  'VG Siddhartha: Cafe Coffee Day owner goes missing near river': 'name',
#  "Costa Coffee: Employees call Â£200 deductions for training 'unfair'": 'name',
#  'Jerry Seinfeld wins copyright lawsuit over Comedians in Cars Getting Coffee': 'name',
#  'Reading coffee shop helping women rebuild their lives': 'name',
#  'Vegan chicken fillet roll copycat row bites Insomnia Coffee': 'name',
#  'A coffee shop in San Francisco offers a $75 cup of coffee': 'name',
#  'Bulletproof coffee: Would you add butter to your brew?': 'name',
#  'San Francisco is serving up a $75 cup of coffee': 'name',
#  "Faf de Klerk: Pants, coffee and Shrek: Q&A with South Africa's World Cup winner": 'name',
#  'Coffee art: Why Ennock Mlangeni swapped paint for the bean': 'name',
#  'Purr-fect place for a coffee': 'name',
#  'Coffee not essential for life, Swiss government says': 'name',
#  "Coffee waste 'could replace palm oil'": 'name',
#  "Coffee cup ban: Boston Tea Party's sales fall by Â£250k": 'name',
#  'Coffee species face extinction, report says': 'name',
#  "Cuppy: Cuppy & Eddie Kadi get heated over pancakes Plus special Cuppy's Coffee Mix": 'name',
#  'Cannabis with your coffee?': 'name',
#  'Wormwood Scrubs inmates train to become coffee baristas': 'name',
#  'Taking the coffee bean to the barista': 'name',
#  "In Business: Colombia's Coffee Revolutions": 'name',
#  'The Florida coffee shop where Trump is king': 'name',
#  'Boston Tea Party coffee chain boss on Â£250k loss': 'name',
#  "Single-use coffee cups: Wales urged to bring in 'latte levy'": 'name',
#  "'Keep Frank's Bethnal Green coffee stand open'": 'name',
#  'Christchurch council refuses permission for new coffee shop': 'name',
#  "Cannabis in coffee: 'Just like having a shot of syrup'": 'name',
#  'The Why Factor: Coffee': 'name',
#  'The Food Chain: Coffee: Globalisationâ\x80\x99s Drink of Choice': 'name',
#  'Global Business: Colombiaâ\x80\x99s Coffee Revolutions': 'name',
#  'The World of Business: Colombiaâ\x80\x99s Coffee Revolutions': 'name',
#  'Your pictures: Coffee time': 'name',
#  'Talks between Douwe Egberts and coffee workers break down': 'name',
#  'Coffee delivery drone patented by IBM': 'name',
#  'Why Bosnian coffee is served with sherbet': 'name',
#  'Coca-Cola to buy Costa coffee for Â£3.9bn': 'name',
#  'Welsh roastery Coaltown Coffee named in Lonely Planet list': 'name',
#  'Coffee: Who grows, drinks and pays the most?': 'name',
#  'The coffee cup which can be recycled in existing systems': 'name',
#  'Best of Friends: Fancy grabbing a coffee at Central Perk?': 'name',
#  "Back to school: 'I'm ready for a coffee in peace'": 'name',
#  'Disposable coffee cup bans unnecessary, says manufacturer': 'name',
#  'Coffee sold in California must carry cancer warning, judge rules': 'name',
#  'Coffee war brews in the land of tea': 'name',
#  'Plastic recycling: Why are 99.75% of coffee cups not recycled?': 'name',
#  "Coffee chain Boston Tea Party 'first' to ban disposable cups": 'name',
#  "Costa Coffee vows 'cup recycling revolution'": 'name',
#  "Liam Williams column: Old friends, no fans and George North's coffee skills": 'name',
#  "Gardeners' Corner: Coffee grounds, sweet pea and Matthew Wilson": 'name',
#  'The Documentary: Your Life in a Cup of Coffee': 'name',
#  'The Documentary Podcast: Your Life in a Cup of Coffee': 'name',
#  "Three cups of coffee a day 'may have health benefits'": 'name',
#  'How changing coffee tastes are helping farmers': 'name',
#  'Costa Coffee advert banned for criticising avocado breakfasts': 'name',
#  'London buses to be powered by coffee': 'name',
#  "'Want a cup of coffee? That'll be $60'": 'name',
#  "Why Italians are saying 'no' to takeaway coffee": 'name',
#  'Smart Consumer: The You and Yours Coffee Break. What are you eating and who are going to you watch?': 'name',
#  'The Italians who prefer to drink American coffee': 'name',
#  'The coffee cups that get you to talk': 'name',
#  'Is the UK reaching coffee shop saturation point?': 'name',
#  'Nestle swallows Blue Bottle Coffee': 'name',
#  "How 'posh coffee' is helping farmers": 'name',
#  'Reading coffee shops offer discount on reusable cups': 'name',
#  'Faecal bacteria found in coffee shop ice after random checks': 'name',
#  "Costa coffee chain's profits go cold": 'name',
#  'CCTV of masked men beating coffee shop staff with bats': 'name',
#  'Four solutions to the disposable coffee cup problem': 'name',
#  'Ellia Smeding & Cornelius Kersten: Speed skating couple using coffee to fund Olympic dream': 'name',
#  'Covid: Portsdown Hill coffee drinker fined for refusing to leave': 'name',
#  "Why Italians are saying 'No' to takeaway coffee": 'name',
#  "'Latte levy': Would you pay 25p for your coffee cup?": 'name',
#  "Ireland considers 'coffee tax' to cut back on disposable cups": 'name',
#  'Will coffee taste worse as the planet warms?': 'name',
#  'Checks on Welsh coffee shops for faecal bacteria in ice': 'name',
#  "'Suspended coffee' initiative taking off in Bristol": 'name',
#  'Orkney gets first coffee roastery': 'name',
#  'Suffolk Rural Coffee Caravan wants to replace stolen vehicle': 'name',
#  'Coffee cup fee could cut use by 300 million, study suggests': 'name',
#  'Coffee cup recycling scheme launched in City of London': 'name',
#  "Costa Coffee's High Street sales fall": 'name',
#  'You and Yours: Christmas Shopping; Coffee Shop decline; Relaxed Tailoring': 'name',
#  'Maths zeroes in on perfect cup of coffee': 'name',
#  'CEO Secrets: Think outside the bubble, says coffee chief': 'name',
#  'What makes your perfect cup of coffee?': 'name',
#  'Manchester launches paper coffee cup recycling campaign': 'name',
#  "Cambridge police cell detainee donates scratchcard win for 'better coffee' in cells": 'name',
#  'Waitrose coffee change gives grounds for complaint': 'name',
#  'Costa coffee owner Whitbread wary over prospects': 'name',
#  "Study finds gene 'that could curb coffee consumption'": 'name',
#  'How do you turn used coffee grounds into clothes?': 'name',
#  'Four Thought: Coffee with an Imam': 'name',
#  'Natalie Bennett angry as GWR refuse coffee in reusable cup': 'name',
#  'Man admits Westerham Costa coffee death crash': 'name',
#  'Glasgow coffee supplier Matthew Algie sold to Tchibo': 'name',
#  "'Hipster coffee' gets Australia hot and frothing": 'name',
#  'Viewpoint: The waste mountain of coffee cups': 'name',
#  'Coffee shops on the march as pubs decline, town centre data shows': 'name',
#  'Why your coffee could cost more': 'name',
#  "Indonesia 'coffee killer' trial: Jessica Wongso found guilty of murder": 'name',
#  "'Russiano' coffee joke sparks online humour": 'name',
#  'Cancer risk from coffee downgraded': 'name',
#  'Is there a serious problem with coffee capsules?': 'name',
#  'Queen portrait created out of 1,600 used coffee pods': 'name',
#  'Costa Coffee helps boost Whitbread profits': 'name',
#  'MSPs call for better quality coffee at Holyrood committee meetings': 'name',
#  'Your pictures: Coffee break': 'name',
#  'Coffee - a Hellish Brew: Slurping Coffee for a Living': 'name',
#  "MSP Mary Scanlon makes plea for 'decent coffee' at Holyrood": 'name',
#  'Westerham Costa Coffee death crash: Man, 86, to face charges': 'name',
#  'Westerham Costa coffee death crash: David Lord charged': 'name',
#  'Discovery: The coffee trade': 'name',
#  'Green entrepreneurs: Coffee for your face, bees for your booze': 'name',
#  'The Farming World: Coffee Fungus Spreads into Uguanda': 'name',
#  'Entrepreneur milks new coffee trend in Ivory Coast': 'name',
#  'Coffee maker Keurig sells to Douwe Egberts owner for $13.9bn': 'name',
#  "Who'd have Thought It?: Coffee": 'name',
#  'Man denies Westerham Costa coffee death crash': 'name',
#  'Spice Taxi: Eritrea Coffee': 'name',
#  'Fancy a cuppa coffee? Lisburn company plans to brew success': 'name',
#  'Llandudno woman was crushed by mobile coffee shop van': 'name',
#  'Coffee - a Hellish Brew: Coffee Growing and Production': 'name',
#  'The Farming World: How can Coffee Growers make a Profit?': 'name'}

# %%
G = nx.Graph(graph_data)
G
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/networkx/convert.py:172, in to_networkx_graph(data, create_using, multigraph_input)
#     171 try:
# --> 172     return from_edgelist(data, create_using=create_using)
#     173 except Exception as err:
#
# File /opt/conda/lib/python3.10/site-packages/networkx/convert.py:490, in from_edgelist(edgelist, create_using)
#     489 G = nx.empty_graph(0, create_using)
# --> 490 G.add_edges_from(edgelist)
#     491 return G
#
# File /opt/conda/lib/python3.10/site-packages/networkx/classes/graph.py:962, in Graph.add_edges_from(self, ebunch_to_add, **attr)
#     961 if v is None:
# --> 962     raise ValueError("None cannot be a node")
#     963 self._adj[v] = self.adjlist_inner_dict_factory()
#
# ValueError: None cannot be a node
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 G = nx.Graph(graph_data)
#       2 G
#
# File /opt/conda/lib/python3.10/site-packages/networkx/classes/graph.py:352, in Graph.__init__(self, incoming_graph_data, **attr)
#     350 # attempt to load graph with data
#     351 if incoming_graph_data is not None:
# --> 352     convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     353 # load graph attributes (must be after convert)
#     354 self.graph.update(attr)
#
# File /opt/conda/lib/python3.10/site-packages/networkx/convert.py:174, in to_networkx_graph(data, create_using, multigraph_input)
#     172         return from_edgelist(data, create_using=create_using)
#     173     except Exception as err:
# --> 174         raise nx.NetworkXError("Input is not a valid edge list") from err
#     176 raise nx.NetworkXError("Input is not a known data type for conversion.")
#
# NetworkXError: Input is not a valid edge list

# %%
node_colors = {elm:'skyblue' if elm in news_titles else 'yellow' for elm in G.nodes()}
node_colors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 node_colors = {elm:'skyblue' if elm in news_titles else 'yellow' for elm in G.nodes()}
#       2 node_colors
#
# NameError: name 'G' is not defined

# %%
# plt.figure(figsize=(16,8))
# nx.draw_kamada_kawai(G, node_size=100)
# plt.show()

# %%
# plt.figure(figsize=(16,8))
# nx.draw_spring(G, node_size=100)
# plt.show()

# %% [markdown]
# ### visualize raw data

# %%
title = "News and NameEntities"
HOVER_TOOLTIPS = [("Character", "@index")]
nx.set_node_attributes(G, node_colors, 'node_colors')
plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
 )

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(size=15, fill_color='node_colors')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)

# %% [markdown]
# ### Compute betweenness_centrality graph

# %%
def cal_size(val, k=10, k2=1000):
    val = val * k * k2
    if val > k: 
        return val
    return k

# %%
graph_values = nx.centrality.betweenness.betweenness_centrality(G)
node_size = {k:cal_size(v, k=10, k2=1000) for k,v in graph_values.items()}

# %%
title = "betweenness_centrality"
HOVER_TOOLTIPS = [("Character", "@index")]

nx.set_node_attributes(G, node_size, 'node_size')
nx.set_node_attributes(G, node_colors, 'node_colors')

plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
)

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(fill_color='node_colors', size='node_size')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)

# %% [markdown]
# ### compute eigenvector_centrality

# %%
graph_values = nx.centrality.eigenvector.eigenvector_centrality(G, max_iter=600)
node_size = {k:cal_size(v, k=10, k2=15) for k,v in graph_values.items()}

# %%
title = "xxx"
HOVER_TOOLTIPS = [("Character", "@index")]

nx.set_node_attributes(G, node_size, 'node_size') 
nx.set_node_attributes(G, node_colors, 'node_colors')

plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset,hover", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title,
              frame_width=1200, frame_height=800
)

network_graph = from_networkx(G, nx.kamada_kawai_layout, scale=10, center=(0, 0))
network_graph.node_renderer.glyph = Circle(fill_color='node_colors', size='node_size')
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.5, line_width=1)
plot.renderers.append(network_graph)
show(plot)
