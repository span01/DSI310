# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
import csv
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 121
dir_process_id = 122

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY4NjcxNzc0LCJpYXQiOjE2Njg1ODUzNzMsImp0aSI6Ijc4OWEzMjg3MzgzNTQ3NGFiYWI5YjAxMWRhNjk2YmZjIiwidXNlcl9pZCI6MTd9.iGBkkI15eAVjuLvwRE1r_oLQtp-fOrJIHdzO27dxFRU"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='Shopee_starfruit.csv'))
meta
# Out:
# {'owner': 'taksaporn',
#  'human_size': '30.09 KB',
#  'name': 'Shopee_starfruit.csv',
#  'description': 'file Shopee_starfruit.csv',
#  'directory': 121,
#  'path': 'taksaporn/DSI310-16/rawData/Shopee_starfruit.csv'}

# %%
data = pd.read_csv('./Shopee_starfruit.csv')
data
# Out:
#      Unnamed: 0                                            Product  price  \
# 0             0  🌱เมล็ดพันธุ์มะเขือเทศเชอรี่กลม🌱 30 เมล็ด  5️⃣เ...      8
# 1             1  มะเดื่อฝรั่ง สายพันธ์ Bordissot Rossa พันธ์จาก...    480
# 2             2  ผลิตภัณฑ์ใหม่ เมล็ดพันธุ์ ผักซอง ศรแดง มะเขือเ...     10
# 3             3  ผลิตภัณฑ์ใหม่ เมล็ดพันธุ์ จุดประเทศไทย ❤พะยูงไ...     39
# 4             4  เมล็ด ผักบุ้ง อินทรีย์ เมล็ดพันธุ์คุณภาพสูงในส...     12
# ..          ...                                                ...    ...
# 115         115                ⭐️ น้ำหมักชีวภาพ มะเฟือง 250 ml. ⭐️     55
# 116         116  ตะกั่วตกปลา ทรงมะเฟือง 20g 30g 40g 50g น้ำหนัก...     20
# 117         117          แม่ใหญ่สมุนไพร โลชั่นมะเฟืองสดผสมขมิ้นชัน     47
# 118         118  🌿ชีวาร์ Chewa🌿เจลล้างหน้าว่านหางจรเข้และสารสกั...    159
# 119         119                 🌈น้ำหมักชีวภาพ มะเฟือง ขจัดสิวฝ้า🌈     55
#
#      sales              province
# 0    38000        จังหวัดนนทบุรี
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      Unnamed: 0                                            Product  price  \
# 0             0  🌱เมล็ดพันธุ์มะเขือเทศเชอรี่กลม🌱 30 เมล็ด  5️⃣เ...      8
# 1             1  มะเดื่อฝรั่ง สายพันธ์ Bordissot Rossa พันธ์จาก...    480
# 2             2  ผลิตภัณฑ์ใหม่ เมล็ดพันธุ์ ผักซอง ศรแดง มะเขือเ...     10
# 3             3  ผลิตภัณฑ์ใหม่ เมล็ดพันธุ์ จุดประเทศไทย ❤พะยูงไ...     39
# 4             4  เมล็ด ผักบุ้ง อินทรีย์ เมล็ดพันธุ์คุณภาพสูงในส...     12
# ..          ...                                                ...    ...
# 115         115                ⭐️ น้ำหมักชีวภาพ มะเฟือง 250 ml. ⭐️     55
# 116         116  ตะกั่วตกปลา ทรงมะเฟือง 20g 30g 40g 50g น้ำหนัก...     20
# 117         117          แม่ใหญ่สมุนไพร โลชั่นมะเฟืองสดผสมขมิ้นชัน     47
# 118         118  🌿ชีวาร์ Chewa🌿เจลล้างหน้าว่านหางจรเข้และสารสกั...    159
# 119         119                 🌈น้ำหมักชีวภาพ มะเฟือง ขจัดสิวฝ้า🌈     55
#
#      sales              province
# 0    38000        จังหวัดนนทบุรี
# ...

# %%
df['Product'] = df['Product'].str[:100]
df = df.rename(columns = {'price' : 'Price'})
df = df.rename(columns = {'sales' : 'Sales'})
df = df.rename(columns = {'province' : 'Province'})
df = df.rename(columns = {'Unnamed: 0' : 'Number'})
df
# Out:
#      Number                                            Product  Price  Sales  \
# 0         0  🌱เมล็ดพันธุ์มะเขือเทศเชอรี่กลม🌱 30 เมล็ด  5️⃣เ...      8  38000
# 1         1  มะเดื่อฝรั่ง สายพันธ์ Bordissot Rossa พันธ์จาก...    480     13
# 2         2  ผลิตภัณฑ์ใหม่ เมล็ดพันธุ์ ผักซอง ศรแดง มะเขือเ...     10      0
# 3         3  ผลิตภัณฑ์ใหม่ เมล็ดพันธุ์ จุดประเทศไทย ❤พะยูงไ...     39      0
# 4         4  เมล็ด ผักบุ้ง อินทรีย์ เมล็ดพันธุ์คุณภาพสูงในส...     12      0
# ..      ...                                                ...    ...    ...
# 115     115                ⭐️ น้ำหมักชีวภาพ มะเฟือง 250 ml. ⭐️     55    261
# 116     116  ตะกั่วตกปลา ทรงมะเฟือง 20g 30g 40g 50g น้ำหนัก...     20     17
# 117     117          แม่ใหญ่สมุนไพร โลชั่นมะเฟืองสดผสมขมิ้นชัน     47     58
# 118     118  🌿ชีวาร์ Chewa🌿เจลล้างหน้าว่านหางจรเข้และสารสกั...    159      4
# 119     119                 🌈น้ำหมักชีวภาพ มะเฟือง ขจัดสิวฝ้า🌈     55    224
#
#                  Province
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="Shopee : Starfruit Scraping", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='Shopee_starfruit.csv')])
# Out:
# {'sucess': True,
#  'file_id': 859,
#  'path': 'taksaporn/DSI310-16/process/Shopee : Starfruit Scraping.parquet',
#  'lineage': True}
