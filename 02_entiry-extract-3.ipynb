# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 4.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 970.2 kB/s eta 0:00:0000:0100:05
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 861.4 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 4.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 1.7 MB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 4.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.8 MB/s eta 0:00:0000:0100:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.2 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
import csv
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 121
dir_process_id = 122

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY4MDEyMDM5LCJpYXQiOjE2NjczNzI2MjcsImp0aSI6ImIyMDNjOTJjYWZmYzQyYjU4YTg5MTQzODgyMDc2ZTdkIiwidXNlcl9pZCI6MTd9.S1Q6CUHJDB3cGt-IuS2puaiYN7hMQl94YA3mFVrXPEk"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='Starfruit_news.csv'))
meta
# Out:
# {'owner': 'taksaporn',
#  'human_size': '129.43 KB',
#  'name': 'Starfruit_news.csv',
#  'description': 'file Starfruit_news.csv',
#  'directory': 121,
#  'path': 'taksaporn/DSI310-16/rawData/Starfruit_news.csv'}

# %%
data = pd.read_csv('./Starfruit_news.csv')
data
# Out:
#     Unnamed: 0                                              topic  \
# 0            0                             มะเฟืองน้ำปลาหวานอร่อย
# 1            1  รู้จัก "มะเฟือง" ให้มากขึ้น กินมะเฟืองแล้วตายจ...
# 2            2                    น้ำมะเฟือง เมนูคลายร้อน แก้ง่วง
# 3            3       แม่เต่ามะเฟืองวางไข่ครั้งที่ 5 หาดท้ายเหมือง
# 4            4         นึกว่ารอยพญานาค!ที่แท้แม่เต่ามะเฟืองวางไข่
# 5            5  หาดูยาก! ดร.ธรณ์ โพสต์คลิปลูกเต่ามะเฟืองกินแมง...
# 6            6  ปลื้ม เต่าทะเลเกาะสมุยวางไข่ 14 รัง ชนะเต่ามะเ...
# 7            7  ตะลิงปลิง  &  มะเฟือง  ผลไม้ต้องห้ามเป็นอันตรา...
# 8            8  ลูกเต่ามะเฟือง รังที่ 18 รังสุดท้ายของฤดูกาล ม...
# 9            9  เฮ! พบเต่ามะเฟือง วางไข่ 100 ฟอง อช.หาดเขาหน้า...
# 10          10  ธรณ์หวั่นเสริมทรายชายหาด ทำ ‘เต่ามะเฟือง’ ไร้ท...
# 11          11  พลังศรัทธา! ยอดบริจาคล่าสุด วัดท่ามะเฟือง พุ่ง...
# 12          12  ลูกเต่ามะเฟืองรังที่ 4 ชายหาดบางขวัญ พังงา ฟัก...
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#     Unnamed: 0                                              topic  \
# 0            0                             มะเฟืองน้ำปลาหวานอร่อย
# 1            1  รู้จัก "มะเฟือง" ให้มากขึ้น กินมะเฟืองแล้วตายจ...
# 2            2                    น้ำมะเฟือง เมนูคลายร้อน แก้ง่วง
# 3            3       แม่เต่ามะเฟืองวางไข่ครั้งที่ 5 หาดท้ายเหมือง
# 4            4         นึกว่ารอยพญานาค!ที่แท้แม่เต่ามะเฟืองวางไข่
# 5            5  หาดูยาก! ดร.ธรณ์ โพสต์คลิปลูกเต่ามะเฟืองกินแมง...
# 6            6  ปลื้ม เต่าทะเลเกาะสมุยวางไข่ 14 รัง ชนะเต่ามะเ...
# 7            7  ตะลิงปลิง  &  มะเฟือง  ผลไม้ต้องห้ามเป็นอันตรา...
# 8            8  ลูกเต่ามะเฟือง รังที่ 18 รังสุดท้ายของฤดูกาล ม...
# 9            9  เฮ! พบเต่ามะเฟือง วางไข่ 100 ฟอง อช.หาดเขาหน้า...
# 10          10  ธรณ์หวั่นเสริมทรายชายหาด ทำ ‘เต่ามะเฟือง’ ไร้ท...
# 11          11  พลังศรัทธา! ยอดบริจาคล่าสุด วัดท่ามะเฟือง พุ่ง...
# 12          12  ลูกเต่ามะเฟืองรังที่ 4 ชายหาดบางขวัญ พังงา ฟัก...
# ...

# %%
df['topic'] = df['topic'].str[:100]
df = df.rename(columns = {'topic' : 'Title'})
df = df.rename(columns = {'detail' : 'Detail'})
df = df.rename(columns = {'link' : 'Link'})
df = df.rename(columns = {'Unnamed: 0' : 'Number'})
df
# Out:
#     Number                                              Title  \
# 0        0                             มะเฟืองน้ำปลาหวานอร่อย
# 1        1  รู้จัก "มะเฟือง" ให้มากขึ้น กินมะเฟืองแล้วตายจ...
# 2        2                    น้ำมะเฟือง เมนูคลายร้อน แก้ง่วง
# 3        3       แม่เต่ามะเฟืองวางไข่ครั้งที่ 5 หาดท้ายเหมือง
# 4        4         นึกว่ารอยพญานาค!ที่แท้แม่เต่ามะเฟืองวางไข่
# 5        5  หาดูยาก! ดร.ธรณ์ โพสต์คลิปลูกเต่ามะเฟืองกินแมง...
# 6        6  ปลื้ม เต่าทะเลเกาะสมุยวางไข่ 14 รัง ชนะเต่ามะเ...
# 7        7  ตะลิงปลิง  &  มะเฟือง  ผลไม้ต้องห้ามเป็นอันตรา...
# 8        8  ลูกเต่ามะเฟือง รังที่ 18 รังสุดท้ายของฤดูกาล ม...
# 9        9  เฮ! พบเต่ามะเฟือง วางไข่ 100 ฟอง อช.หาดเขาหน้า...
# 10      10  ธรณ์หวั่นเสริมทรายชายหาด ทำ ‘เต่ามะเฟือง’ ไร้ท...
# 11      11  พลังศรัทธา! ยอดบริจาคล่าสุด วัดท่ามะเฟือง พุ่ง...
# 12      12  ลูกเต่ามะเฟืองรังที่ 4 ชายหาดบางขวัญ พังงา ฟัก...
# 13      13  พบแม่เต่ามะเฟืองขึ้นวางไข่ร่วมร้อยฟองออกนอกฤดู...
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="News : Starfruit news Scraping", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='Starfruit_news.csv')])
# Out:
# {'sucess': True,
#  'file_id': 647,
#  'path': 'taksaporn/DSI310-16/process/News : Starfruit news Scraping.parquet',
#  'lineage': True}
