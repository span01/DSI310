# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f23dcf3cb80>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/transformers/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f23dcf3ceb0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/transformers/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f23dcf3d150>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/transformers/
# ...

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
import csv
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 121
dir_process_id = 122

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjcxMTIxODU4LCJpYXQiOjE2NzEwMzU0NTgsImp0aSI6IjQ4NzZmODEzYjBmNjQ2NTA5MzlmNjUxNGY3NjIxYjU2IiwidXNlcl9pZCI6MTd9.9KYjqGtWGfp3mpWGp3k3Pg_ThX7QYxnGEZLu9ZcvJPg"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='shopee_coffee_readytodrink.csv'))
meta
# Out:
# {'owner': 'taksaporn',
#  'human_size': '58.74 KB',
#  'name': 'shopee_coffee_readytodrink.csv',
#  'description': 'file shopee_coffee_readytodrink.csv',
#  'directory': 121,
#  'path': 'taksaporn/DSI310-16/rawData/shopee_coffee_readytodrink.csv'}

# %%
data = pd.read_csv('./shopee_coffee_readytodrink.csv')
data
# Out:
#                                                Product  price   sales  \
# 0    Lamoon Cold Brew Concentrate 200 ml. กาแฟสกัดเ...     75   18000
# 1               Ajinomoto อายิโนะโมะโต๊ะผงชูรส 500กรัม     57   23000
# 2    Birdy Robusta 180 ml. x 6 Cans Birdy เบอร์ดี้ ...     90  579000
# 3    Birdy Robusta Low Sugar 180 ml.  X 30 cans เบอ...    385     544
# 4    Starbucks/COSTA/GIMOKA/KIMBO กาแฟ สตาร์บัคส์ บ...     59    4000
# ..                                                 ...    ...     ...
# 235  [+CODE11.15]📌ส่งฟรี+แถมแก้ว📌เมล็ดกาแฟดอยช้าง ค...    629   67000
# 236  กาแฟทรีเมจิก 5in1ไม่มีน้ำตาล ขนาด 1 ห่อ 50 ซอง...    219   47000
# 237  PK French Roast ขนาด 1,000g. เมล็ดกาแฟคั่วเข้ม...    313   52000
# 238  Birdy Black Zero 180 ml. X 6 cans เบอร์ดี้ แบล...     90   11000
# 239  (ซื้อ2แถมเซ็ททดลอง) 1ถุงมี 25 ซอง โกโก้ คุมหิว...     68    3000
#
#                  province
# 0        จังหวัดเชียงใหม่
# 1      จังหวัดสมุทรปราการ
# 2      จังหวัดสมุทรปราการ
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                Product  price   sales  \
# 0    Lamoon Cold Brew Concentrate 200 ml. กาแฟสกัดเ...     75   18000
# 1               Ajinomoto อายิโนะโมะโต๊ะผงชูรส 500กรัม     57   23000
# 2    Birdy Robusta 180 ml. x 6 Cans Birdy เบอร์ดี้ ...     90  579000
# 3    Birdy Robusta Low Sugar 180 ml.  X 30 cans เบอ...    385     544
# 4    Starbucks/COSTA/GIMOKA/KIMBO กาแฟ สตาร์บัคส์ บ...     59    4000
# ..                                                 ...    ...     ...
# 235  [+CODE11.15]📌ส่งฟรี+แถมแก้ว📌เมล็ดกาแฟดอยช้าง ค...    629   67000
# 236  กาแฟทรีเมจิก 5in1ไม่มีน้ำตาล ขนาด 1 ห่อ 50 ซอง...    219   47000
# 237  PK French Roast ขนาด 1,000g. เมล็ดกาแฟคั่วเข้ม...    313   52000
# 238  Birdy Black Zero 180 ml. X 6 cans เบอร์ดี้ แบล...     90   11000
# 239  (ซื้อ2แถมเซ็ททดลอง) 1ถุงมี 25 ซอง โกโก้ คุมหิว...     68    3000
#
#                  province
# 0        จังหวัดเชียงใหม่
# 1      จังหวัดสมุทรปราการ
# 2      จังหวัดสมุทรปราการ
# ...

# %%
df['Product'] = df['Product'].str[:100]
df = df.rename(columns = {'price' : 'Price'})
df = df.rename(columns = {'sales' : 'Sales'})
df = df.rename(columns = {'province' : 'Province'})
df = df.rename(columns = {'Unnamed: 0' : 'Number'})
df
# Out:
#                                                Product  Price   Sales  \
# 0    Lamoon Cold Brew Concentrate 200 ml. กาแฟสกัดเ...     75   18000
# 1               Ajinomoto อายิโนะโมะโต๊ะผงชูรส 500กรัม     57   23000
# 2    Birdy Robusta 180 ml. x 6 Cans Birdy เบอร์ดี้ ...     90  579000
# 3    Birdy Robusta Low Sugar 180 ml.  X 30 cans เบอ...    385     544
# 4    Starbucks/COSTA/GIMOKA/KIMBO กาแฟ สตาร์บัคส์ บ...     59    4000
# ..                                                 ...    ...     ...
# 235  [+CODE11.15]📌ส่งฟรี+แถมแก้ว📌เมล็ดกาแฟดอยช้าง ค...    629   67000
# 236  กาแฟทรีเมจิก 5in1ไม่มีน้ำตาล ขนาด 1 ห่อ 50 ซอง...    219   47000
# 237  PK French Roast ขนาด 1,000g. เมล็ดกาแฟคั่วเข้ม...    313   52000
# 238  Birdy Black Zero 180 ml. X 6 cans เบอร์ดี้ แบล...     90   11000
# 239  (ซื้อ2แถมเซ็ททดลอง) 1ถุงมี 25 ซอง โกโก้ คุมหิว...     68    3000
#
#                  Province
# 0        จังหวัดเชียงใหม่
# 1      จังหวัดสมุทรปราการ
# 2      จังหวัดสมุทรปราการ
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="Shopee : Ready to drink coffee Scraping", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='shopee_coffee_readytodrink.csv')])
# Out:
# {'sucess': True,
#  'file_id': 1024,
#  'path': 'taksaporn/DSI310-16/process/Shopee : Ready to drink coffee Scraping.parquet',
#  'lineage': True}
