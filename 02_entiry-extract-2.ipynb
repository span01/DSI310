# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
import csv
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 121
dir_process_id = 122

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY3MzE3NTU0LCJpYXQiOjE2NjY2Nzk3NTEsImp0aSI6ImZjMzMzYzk0ODRhYjRlMzRiN2MwMjBjOWIxZTA3YTg0IiwidXNlcl9pZCI6MTd9.06gg0kMB7G429spshFFkZfEGd6XLyBW9xtHMPF_lbC8"
datanode = DataNode(token = token)
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='Shopee_FruitCoffee.csv'))
meta
# Out:
# {'owner': 'taksaporn',
#  'human_size': '48.71 KB',
#  'name': 'Shopee_FruitCoffee.csv',
#  'description': 'file Shopee_FruitCoffee.csv',
#  'directory': 121,
#  'path': 'taksaporn/DSI310-16/rawData/Shopee_FruitCoffee.csv'}

# %%
data = pd.read_csv('./Shopee_FruitCoffee.csv')
data
# Out:
#      Unnamed: 0                                            Product  price  \
# 0             0  กาแฟสกัดเย็น Peaberry Reserve Cold Brew  [กลมก...    534
# 1             1        โซลิโต้ เมล็ดกาแฟคั่ว ออแกนิคโค่ (500 กรัม)    608
# 2             2  Huan Roastery << GOOD DAY>>  เมล็ดกาแฟคั่วกลาง...    180
# 3             3  โซลิโต้ เมล็ดกาแฟคั่ว เอสเพรสโซ่ พรีเมี่ยม เบล...    329
# 4             4  FATIS COFFEE กาแฟฟาทีส 24 กล่อง (กล่องละ 15 ซอ...   4390
# ..          ...                                                ...    ...
# 175         175  Tanmonkey Blend Coffee MilkKing เมล็ดกาแฟคั่วร...    220
# 176         176       Baramio เมล็ดกาแฟคั่วรุ่น Slow Dry 200/500g.    255
# 177         177  กาแฟคั่วกลาง หอมกลมกล่อมที่สุด  กลิ่นหอมละมุน ...    139
# 178         178                Birdy 3in1 กาแฟเอสเปรสโซ แพค 60 ซอง    173
# 179         179  Tanmonkey Coffee เมล็ดกาแฟคั่ว Brazil Santos C...    350
#
#      sales              province
# 0        7      จังหวัดเชียงใหม่
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      Unnamed: 0                                            Product  price  \
# 0             0  กาแฟสกัดเย็น Peaberry Reserve Cold Brew  [กลมก...    534
# 1             1        โซลิโต้ เมล็ดกาแฟคั่ว ออแกนิคโค่ (500 กรัม)    608
# 2             2  Huan Roastery << GOOD DAY>>  เมล็ดกาแฟคั่วกลาง...    180
# 3             3  โซลิโต้ เมล็ดกาแฟคั่ว เอสเพรสโซ่ พรีเมี่ยม เบล...    329
# 4             4  FATIS COFFEE กาแฟฟาทีส 24 กล่อง (กล่องละ 15 ซอ...   4390
# ..          ...                                                ...    ...
# 175         175  Tanmonkey Blend Coffee MilkKing เมล็ดกาแฟคั่วร...    220
# 176         176       Baramio เมล็ดกาแฟคั่วรุ่น Slow Dry 200/500g.    255
# 177         177  กาแฟคั่วกลาง หอมกลมกล่อมที่สุด  กลิ่นหอมละมุน ...    139
# 178         178                Birdy 3in1 กาแฟเอสเปรสโซ แพค 60 ซอง    173
# 179         179  Tanmonkey Coffee เมล็ดกาแฟคั่ว Brazil Santos C...    350
#
#      sales              province
# 0        7      จังหวัดเชียงใหม่
# ...

# %%
df['Product'] = df['Product'].str[:100]
df = df.rename(columns = {'price' : 'Price'})
df = df.rename(columns = {'sales' : 'Sales'})
df = df.rename(columns = {'province' : 'Province'})
df = df.rename(columns = {'Unnamed: 0' : 'Number'})
df
# Out:
#      Number                                            Product  Price  Sales  \
# 0         0  กาแฟสกัดเย็น Peaberry Reserve Cold Brew  [กลมก...    534      7
# 1         1        โซลิโต้ เมล็ดกาแฟคั่ว ออแกนิคโค่ (500 กรัม)    608      0
# 2         2  Huan Roastery << GOOD DAY>>  เมล็ดกาแฟคั่วกลาง...    180     55
# 3         3  โซลิโต้ เมล็ดกาแฟคั่ว เอสเพรสโซ่ พรีเมี่ยม เบล...    329      1
# 4         4  FATIS COFFEE กาแฟฟาทีส 24 กล่อง (กล่องละ 15 ซอ...   4390     39
# ..      ...                                                ...    ...    ...
# 175     175  Tanmonkey Blend Coffee MilkKing เมล็ดกาแฟคั่วร...    220  15000
# 176     176       Baramio เมล็ดกาแฟคั่วรุ่น Slow Dry 200/500g.    255  17000
# 177     177  กาแฟคั่วกลาง หอมกลมกล่อมที่สุด  กลิ่นหอมละมุน ...    139     98
# 178     178                Birdy 3in1 กาแฟเอสเปรสโซ แพค 60 ซอง    173  38000
# 179     179  Tanmonkey Coffee เมล็ดกาแฟคั่ว Brazil Santos C...    350    107
#
#                  Province
# ...

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="Shopee : Fruit Coffee Scraping", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='Shopee_FruitCoffee.csv')])
# Out:
# {'sucess': True,
#  'file_id': 297,
#  'path': 'taksaporn/DSI310-16/process/Shopee : Fruit Coffee Scraping.parquet',
#  'lineage': True}
